# %% [markdown]
# # lambda * loss1 + (1 - lambda) * loss2

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)

def cnn_model_fn(features, labels, mode):
  """Model function for CNN."""
  # Input Layer
  # Reshape X to 4-D tensor: [batch_size, width, height, channels]
  # MNIST images are 28x28 pixels, and have one color channel
  input_layer = tf.reshape(features["x"], [-1, 28, 28, 1])
  print("_THIS_",type(features))
  # Convolutional Layer #1
  # Computes 32 features using a 5x5 filter with ReLU activation.
  # Padding is added to preserve width and height.
  # Input Tensor Shape: [batch_size, 28, 28, 1]
  # Output Tensor Shape: [batch_size, 28, 28, 32]
  conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=32,
      kernel_size=[5, 5],
      padding="same",
      activation=tf.nn.relu)

  # Pooling Layer #1
  # First max pooling layer with a 2x2 filter and stride of 2
  # Input Tensor Shape: [batch_size, 28, 28, 32]
  # Output Tensor Shape: [batch_size, 14, 14, 32]
  pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)

  # Convolutional Layer #2
  # Computes 64 features using a 5x5 filter.
  # Padding is added to preserve width and height.
  # Input Tensor Shape: [batch_size, 14, 14, 32]
  # Output Tensor Shape: [batch_size, 14, 14, 64]
  conv2 = tf.layers.conv2d(
      inputs=pool1,
      filters=64,
      kernel_size=[5, 5],
      padding="same",
      activation=tf.nn.relu)

  # Pooling Layer #2
  # Second max pooling layer with a 2x2 filter and stride of 2
  # Input Tensor Shape: [batch_size, 14, 14, 64]
  # Output Tensor Shape: [batch_size, 7, 7, 64]
  pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)

  # Flatten tensor into a batch of vectors
  # Input Tensor Shape: [batch_size, 7, 7, 64]
  # Output Tensor Shape: [batch_size, 7 * 7 * 64]
  pool2_flat = tf.reshape(pool2, [-1, 7 * 7 * 64])

  # Dense Layer
  # Densely connected layer with 1024 neurons
  # Input Tensor Shape: [batch_size, 7 * 7 * 64]
  # Output Tensor Shape: [batch_size, 1024]
  dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)

  # Add dropout operation; 0.6 probability that element will be kept
  dropout = tf.layers.dropout(
      inputs=dense, rate=0.4, training=mode == tf.estimator.ModeKeys.TRAIN)

  # Logits layer
  # Input Tensor Shape: [batch_size, 1024]
  # Output Tensor Shape: [batch_size, 10]
  logits = tf.layers.dense(inputs=dropout, units=10)

  predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits/temprature, name="softmax_tensor")
  }
  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

  # Calculate Loss (for both TRAIN and EVAL modes)
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

  # Configure the Training Op (for TRAIN mode)
  if mode == tf.estimator.ModeKeys.TRAIN:
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(
        loss=loss,
        global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

  # Add evaluation metrics (for EVAL mode)
  eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predictions["classes"]),
  }
  return tf.estimator.EstimatorSpec(
      mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
#cross entropy between two logits with temperature applied
#returns a 1d array with loss for each row in the inputs
def cross_entropy2(tar_soft_t, pred_logits):
   pred_soft_t = tf.nn.softmax(pred_logits/temprature)
#    tar_soft = tf.nn.softmax(tar_logits_t/temprature)
   pred_log = -1 * tf.log(pred_soft_t)
   product =tf.multiply(tar_soft_t,pred_log)
#    print("Swapnil", pred_log,tar_soft_t,product)
   return tf.reduce_mean(product)
    
def custom_loss(y_true, pred_logits, tar_soft_t):
#    print(tf.losses.sparse_softmax_cross_entropy(labels = y_true, logits = pred_logits))
#    print(l * cross_entropy2(tar_soft_t, pred_logits_t))
#    return loss_weight * tf.losses.sparse_softmax_cross_entropy(labels = y_true, logits = pred_logits) + (1-loss_weight) * cross_entropy2(tar_soft_t, pred_logits_t)
  return  loss_weight * tf.losses.sparse_softmax_cross_entropy(labels = y_true, logits = pred_logits)+(1-loss_weight)*cross_entropy2(tar_soft_t,pred_logits)
#     one_hot=tf.one_hot(y_true,10)
#     sess2=tf.InteractiveSession()
#     tf.train.start_queue_runners(sess2)
#     print("S_",tar_soft_t.eval())
#     print("T_",pred_soft_t.eval())
#     sess2.close()
#     return tf.losses.mean_squared_error(labels=tar_soft_t,predictions=pred_soft_t)

# %%
def getFilterData(f,l):
  sess=tf.InteractiveSession()
  tf.train.start_queue_runners(sess)
  data_s=f['x'].eval()
  out_s=l.eval()
  sess.close()
  return data_s,out_s


def student_model_fn(features, labels, mode):

  print(features,labels)
  data_swap,out_swap=getFilterData(features,labels)
  # Input Layer
  # Reshape X to 4-D tensor: [batch_size, width, height, channels]
  # MNIST images are 28x28 pixels, and have one color channel
  input_layer = tf.reshape(features["x"], [-1, 28, 28, 1])
  # Convolutional Layer #1
  # Computes 32 features using a 5x5 filter with ReLU activation.
  # Padding is added to preserve width and height.
  # Input Tensor Shape: [batch_size, 28, 28, 1]
  # Output Tensor Shape: [batch_size, 28, 28, 32]
  if mode == tf.estimator.ModeKeys.TRAIN:
      eval_teacher_fn = tf.estimator.inputs.numpy_input_fn(
          x={"x":data_swap},
          y=out_swap,
          batch_size=100,
          shuffle=False)

      eval_teacher=mnist_classifier.evaluate(input_fn=eval_teacher_fn)
      outlog.write('%f;' % eval_teacher['accuracy'])
      outlog.write('%f;' % eval_teacher['loss'])
      outlog.write('\n')
      predictions=mnist_classifier.predict(input_fn=eval_teacher_fn)
      teacher_pred=list(predictions)
      teacher_soft=[ p['probabilities'] for p in teacher_pred]
      temp=np.array(teacher_soft)
      
      teacher_soft_t=tf.convert_to_tensor(temp)


  conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=8,
      kernel_size=[5, 5],
      padding="same",
      activation=tf.nn.relu)

  # Pooling Layer #1
  # First max pooling layer with a 2x2 filter and stride of 2
  # Input Tensor Shape: [batch_size, 28, 28, 32]
  # Output Tensor Shape: [batch_size, 14, 14, 32]
  pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)

  # Convolutional Layer #2
  # Computes 64 features using a 5x5 filter.
  # Padding is added to preserve width and height.
  # Input Tensor Shape: [batch_size, 14, 14, 32]
  # Output Tensor Shape: [batch_size, 14, 14, 64]
  conv2 = tf.layers.conv2d(
      inputs=pool1,
      filters=8,
      kernel_size=[5, 5],
      padding="same",
      activation=tf.nn.relu)

  # Pooling Layer #2
  # Second max pooling layer with a 2x2 filter and stride of 2
  # Input Tensor Shape: [batch_size, 14, 14, 64]
  # Output Tensor Shape: [batch_size, 7, 7, 64]
  pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)

  # Flatten tensor into a batch of vectors
  # Input Tensor Shape: [batch_size, 7, 7, 64]
  # Output Tensor Shape: [batch_size, 7 * 7 * 64]
  pool2_flat = tf.reshape(pool2, [-1, 7 * 7 * 8])

  # Dense Layer
  # Densely connected layer with 1024 neurons
  # Input Tensor Shape: [batch_size, 7 * 7 * 64]
  # Output Tensor Shape: [batch_size, 1024]
  dense = tf.layers.dense(inputs=pool2_flat, units=256, activation=tf.nn.relu)

  # Add dropout operation; 0.6 probability that element will be kept
  dropout = tf.layers.dropout(
      inputs=dense, rate=0.4, training=mode == tf.estimator.ModeKeys.TRAIN)

  # Logits layer
  # Input Tensor Shape: [batch_size, 1024]
  # Output Tensor Shape: [batch_size, 10]
  logits = tf.layers.dense(inputs=dropout, units=10)

  predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
  }
  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

  # Calculate Loss (for both TRAIN and EVAL modes)
  #   loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
  
    
#   student_pred=predictions['probabilities']
#   sess1=tf.InteractiveSession()
#   tf.train.start_queue_runners(sess1)
#   student_soft=student_pred.eval()
#   sess1.close()  
  if mode == tf.estimator.ModeKeys.TRAIN:
#     pred_soft_t=tf.nn.softmax(logits, name="softmax_tensor")
#     print('a',labels,'b', logits,'c', teacher_soft_t ,'d', pred_logits_t)
    loss=custom_loss(labels, logits,teacher_soft_t)
  else:
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
  
    
  # Configure the Training Op (for TRAIN mode)
  if mode == tf.estimator.ModeKeys.TRAIN:
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(
        loss=loss,
        global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

  # Add evaluation metrics (for EVAL mode)
  eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predictions["classes"]),
  }
  return tf.estimator.EstimatorSpec(
      mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
mnist_classifier = tf.estimator.Estimator(
  model_fn=cnn_model_fn, model_dir="./models/mnist_convnet_model_test1")

mnist = tf.contrib.learn.datasets.load_dataset("mnist")
train_data = mnist.train.images  # Returns np.array
train_labels = np.asarray(mnist.train.labels, dtype=np.int32)
eval_data = mnist.test.images  # Returns np.array
eval_labels = np.asarray(mnist.test.labels, dtype=np.int32)
temp_list=[1,2,5,10]
loss_weight_list=[0,0.25,0.5,0.75,1]
p=-1
l=-1
def getdatap():
    global p
    p += 1
    if p>len(train_labels)/100:
        p=0
    data=train_data[p*100:(p+1)*100]
    labels=train_labels[p*100:(p+1)*100]
    
    datatensor=tf.convert_to_tensor(data)
    labeltensor=tf.convert_to_tensor(labels)
    
    
    return {'x':datatensor},labeltensor

out = open('swapout4.csv', 'w')
outlog = open('out_log.csv', 'w')

for i in temp_list:
    for j in loss_weight_list:
        temprature=i
        loss_weight=j
        # Create the Estimator
        student_classifier = tf.estimator.Estimator(
          model_fn=student_model_fn, model_dir="./models/mnist_convnet_student_mod_t_"+str(i)+"_w_"+str(j))

        
#         eval_train_fn = tf.estimator.inputs.numpy_input_fn(
#           x={"x": train_data[:100]},
#           y=train_labels[:100],
#           num_epochs=1,
#           batch_size=100,
#           shuffle=False)
#         train_result=mnist_classifier.evaluate(input_fn=eval_train_fn)
#         #print("\n \n \n Train 100",train_result)
#         print("\n\n\nLABEL FUNCTION",train_labels[:100])
#         print("\n\n\nTRAIN DATA FUNCTION",train_data[0])
        
        # Train the model
#         train_input_fn = tf.estimator.inputs.numpy_input_fn(
#           x={"x": train_data},
#           y=train_labels,
#           batch_size=100,
#           num_epochs=None,
#           shuffle=True)
#         print(train_data,train_labels,eval_data,eval_labels)

        
        student_classifier.train(
          input_fn=getdatap,
          steps=5000,
          hooks=None)
        # print("eva",type(eval_data))

        # Evaluate the model and print results
        eval_train_fn = tf.estimator.inputs.numpy_input_fn(
          x={"x": train_data},
          y=train_labels,
          shuffle=False)
        train_result=student_classifier.evaluate(input_fn=eval_train_fn)
        
        out.write('%f;' % i)
        out.write('%f;' % j)
        out.write('%f;' % train_result['accuracy'])
        out.write('%f;' % train_result['loss'])
        
        eval_input_fn = tf.estimator.inputs.numpy_input_fn(
          x={"x": eval_data},
          y=eval_labels,
          num_epochs=1,
          shuffle=False)
        eval_result=student_classifier.evaluate(input_fn=eval_input_fn)
        # output=list(predictions)
        
        out.write('%f;' % eval_result['accuracy'])
        out.write('%f;' % eval_result['loss'])
#         acc=eval_result
#         out.write(eval_result)
        out.write('\n')
        
out.close()
outlog.close()
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f259779c390>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/tmp/mnist_convnet_model_test1', '_save_summary_steps': 100}
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2596dea910>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './mnist_convnet_student_mod_t_1_w_0', '_save_summary_steps': 100}
# {'x': <tf.Tensor 'Const:0' shape=(100, 784) dtype=float32>} Tensor("Const_1:0", shape=(100,), dtype=int32, device=/device:CPU:0)
# _THIS_ <type 'dict'>
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:48:43
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:48:43
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.97, global_step = 20000, loss = 0.09232447
# _THIS_ <type 'dict'>
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0/model.ckpt-10020
# INFO:tensorflow:Saving checkpoints for 10021 into ./mnist_convnet_student_mod_t_1_w_0/model.ckpt.
# INFO:tensorflow:loss = 0.19398823, step = 10021
# INFO:tensorflow:global_step/sec: 167.04
# INFO:tensorflow:loss = 0.1987425, step = 10121 (0.598 sec)
# INFO:tensorflow:global_step/sec: 185.579
# INFO:tensorflow:loss = 0.1951468, step = 10221 (0.539 sec)
# INFO:tensorflow:global_step/sec: 193.789
# INFO:tensorflow:loss = 0.19410446, step = 10321 (0.516 sec)
# INFO:tensorflow:global_step/sec: 195.192
# INFO:tensorflow:loss = 0.19487633, step = 10421 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.241
# INFO:tensorflow:loss = 0.1955357, step = 10521 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.281
# INFO:tensorflow:loss = 0.19140543, step = 10621 (0.517 sec)
# INFO:tensorflow:global_step/sec: 196.04
# INFO:tensorflow:loss = 0.18959509, step = 10721 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.046
# INFO:tensorflow:loss = 0.18665151, step = 10821 (0.518 sec)
# INFO:tensorflow:global_step/sec: 191.181
# INFO:tensorflow:loss = 0.1844777, step = 10921 (0.523 sec)
# INFO:tensorflow:global_step/sec: 195.384
# INFO:tensorflow:loss = 0.19076332, step = 11021 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.99
# INFO:tensorflow:loss = 0.18424754, step = 11121 (0.519 sec)
# INFO:tensorflow:global_step/sec: 177.417
# INFO:tensorflow:loss = 0.18396184, step = 11221 (0.558 sec)
# INFO:tensorflow:global_step/sec: 189.271
# INFO:tensorflow:loss = 0.18703231, step = 11321 (0.528 sec)
# INFO:tensorflow:global_step/sec: 190.084
# INFO:tensorflow:loss = 0.18450232, step = 11421 (0.526 sec)
# INFO:tensorflow:global_step/sec: 192.719
# INFO:tensorflow:loss = 0.18378916, step = 11521 (0.520 sec)
# INFO:tensorflow:global_step/sec: 195.258
# INFO:tensorflow:loss = 0.1814044, step = 11621 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.372
# INFO:tensorflow:loss = 0.1754249, step = 11721 (0.511 sec)
# INFO:tensorflow:global_step/sec: 194.919
# INFO:tensorflow:loss = 0.17631948, step = 11821 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.296
# INFO:tensorflow:loss = 0.17804728, step = 11921 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.18
# INFO:tensorflow:loss = 0.18235749, step = 12021 (0.514 sec)
# INFO:tensorflow:global_step/sec: 192.873
# INFO:tensorflow:loss = 0.17650278, step = 12121 (0.519 sec)
# INFO:tensorflow:global_step/sec: 194.149
# INFO:tensorflow:loss = 0.17260483, step = 12221 (0.515 sec)
# INFO:tensorflow:global_step/sec: 195.345
# INFO:tensorflow:loss = 0.17551845, step = 12321 (0.512 sec)
# INFO:tensorflow:global_step/sec: 196.067
# INFO:tensorflow:loss = 0.17242403, step = 12421 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.172
# INFO:tensorflow:loss = 0.16793816, step = 12521 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.108
# INFO:tensorflow:loss = 0.17531049, step = 12621 (0.510 sec)
# INFO:tensorflow:global_step/sec: 189.724
# INFO:tensorflow:loss = 0.17175491, step = 12721 (0.527 sec)
# INFO:tensorflow:global_step/sec: 195.374
# INFO:tensorflow:loss = 0.16483389, step = 12821 (0.512 sec)
# INFO:tensorflow:global_step/sec: 196.038
# INFO:tensorflow:loss = 0.167335, step = 12921 (0.510 sec)
# INFO:tensorflow:global_step/sec: 192.547
# INFO:tensorflow:loss = 0.16727018, step = 13021 (0.519 sec)
# INFO:tensorflow:global_step/sec: 195.448
# INFO:tensorflow:loss = 0.16824523, step = 13121 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.573
# INFO:tensorflow:loss = 0.16318339, step = 13221 (0.511 sec)
# INFO:tensorflow:global_step/sec: 192.965
# INFO:tensorflow:loss = 0.16338886, step = 13321 (0.518 sec)
# INFO:tensorflow:global_step/sec: 194.919
# INFO:tensorflow:loss = 0.16123928, step = 13421 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.506
# INFO:tensorflow:loss = 0.16111875, step = 13521 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.142
# INFO:tensorflow:loss = 0.16225067, step = 13621 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.669
# INFO:tensorflow:loss = 0.15708558, step = 13721 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.753
# INFO:tensorflow:loss = 0.16710617, step = 13821 (0.513 sec)
# INFO:tensorflow:global_step/sec: 192.533
# INFO:tensorflow:loss = 0.16094604, step = 13921 (0.519 sec)
# INFO:tensorflow:global_step/sec: 196.232
# INFO:tensorflow:loss = 0.15983906, step = 14021 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.354
# INFO:tensorflow:loss = 0.15933946, step = 14121 (0.517 sec)
# INFO:tensorflow:global_step/sec: 196.321
# INFO:tensorflow:loss = 0.1573923, step = 14221 (0.509 sec)
# INFO:tensorflow:global_step/sec: 195.3
# INFO:tensorflow:loss = 0.1474517, step = 14321 (0.512 sec)
# INFO:tensorflow:global_step/sec: 193.302
# INFO:tensorflow:loss = 0.15153055, step = 14421 (0.517 sec)
# INFO:tensorflow:global_step/sec: 195.036
# INFO:tensorflow:loss = 0.1500033, step = 14521 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.635
# INFO:tensorflow:loss = 0.14352494, step = 14621 (0.514 sec)
# INFO:tensorflow:global_step/sec: 196.341
# INFO:tensorflow:loss = 0.14691484, step = 14721 (0.509 sec)
# INFO:tensorflow:global_step/sec: 195.223
# INFO:tensorflow:loss = 0.15280002, step = 14821 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.793
# INFO:tensorflow:loss = 0.1514114, step = 14921 (0.511 sec)
# INFO:tensorflow:Saving checkpoints for 15020 into ./mnist_convnet_student_mod_t_1_w_0/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14711124.
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:49:10
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0/model.ckpt-15020
# Exception in thread Thread-1073:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:49:12
# INFO:tensorflow:Saving dict for global step 15020: accuracy = 0.5368207, global_step = 15020, loss = 1.5864601
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:49:12
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0/model.ckpt-15020
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:49:13
# INFO:tensorflow:Saving dict for global step 15020: accuracy = 0.5261023, global_step = 15020, loss = 1.579772
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f25977ebc90>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './mnist_convnet_student_mod_t_1_w_0.25', '_save_summary_steps': 100}
# {'x': <tf.Tensor 'Const:0' shape=(100, 784) dtype=float32>} Tensor("Const_1:0", shape=(100,), dtype=int32, device=/device:CPU:0)
# _THIS_ <type 'dict'>
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:49:13
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:49:13
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.96, global_step = 20000, loss = 0.17090626
# _THIS_ <type 'dict'>
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.25/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into ./mnist_convnet_student_mod_t_1_w_0.25/model.ckpt.
# INFO:tensorflow:loss = 0.085419044, step = 10001
# INFO:tensorflow:global_step/sec: 175.083
# INFO:tensorflow:loss = 0.10168868, step = 10101 (0.572 sec)
# INFO:tensorflow:global_step/sec: 195.815
# INFO:tensorflow:loss = 0.09136477, step = 10201 (0.511 sec)
# INFO:tensorflow:global_step/sec: 194.673
# INFO:tensorflow:loss = 0.10917812, step = 10301 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.825
# INFO:tensorflow:loss = 0.10660365, step = 10401 (0.513 sec)
# INFO:tensorflow:global_step/sec: 192.861
# INFO:tensorflow:loss = 0.09908785, step = 10501 (0.519 sec)
# INFO:tensorflow:global_step/sec: 194.405
# INFO:tensorflow:loss = 0.09895761, step = 10601 (0.514 sec)
# INFO:tensorflow:global_step/sec: 192.298
# INFO:tensorflow:loss = 0.097034395, step = 10701 (0.520 sec)
# INFO:tensorflow:global_step/sec: 195.411
# INFO:tensorflow:loss = 0.084896445, step = 10801 (0.512 sec)
# INFO:tensorflow:global_step/sec: 192.673
# INFO:tensorflow:loss = 0.08662553, step = 10901 (0.519 sec)
# INFO:tensorflow:global_step/sec: 191.815
# INFO:tensorflow:loss = 0.088229015, step = 11001 (0.521 sec)
# INFO:tensorflow:global_step/sec: 194.226
# INFO:tensorflow:loss = 0.08562848, step = 11101 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.059
# INFO:tensorflow:loss = 0.100398555, step = 11201 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.199
# INFO:tensorflow:loss = 0.09110738, step = 11301 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.505
# INFO:tensorflow:loss = 0.07138172, step = 11401 (0.514 sec)
# INFO:tensorflow:global_step/sec: 196.756
# INFO:tensorflow:loss = 0.08646821, step = 11501 (0.508 sec)
# INFO:tensorflow:global_step/sec: 186.966
# INFO:tensorflow:loss = 0.07591409, step = 11601 (0.535 sec)
# INFO:tensorflow:global_step/sec: 194.617
# INFO:tensorflow:loss = 0.08543021, step = 11701 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.852
# INFO:tensorflow:loss = 0.07586555, step = 11801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 193.933
# INFO:tensorflow:loss = 0.08778496, step = 11901 (0.516 sec)
# INFO:tensorflow:global_step/sec: 195.648
# INFO:tensorflow:loss = 0.0712606, step = 12001 (0.511 sec)
# INFO:tensorflow:global_step/sec: 194.579
# INFO:tensorflow:loss = 0.08352283, step = 12101 (0.514 sec)
# INFO:tensorflow:global_step/sec: 193.814
# INFO:tensorflow:loss = 0.08483952, step = 12201 (0.518 sec)
# INFO:tensorflow:global_step/sec: 189.225
# INFO:tensorflow:loss = 0.086542346, step = 12301 (0.528 sec)
# INFO:tensorflow:global_step/sec: 196.823
# INFO:tensorflow:loss = 0.07492749, step = 12401 (0.507 sec)
# INFO:tensorflow:global_step/sec: 195.714
# INFO:tensorflow:loss = 0.07605912, step = 12501 (0.511 sec)
# INFO:tensorflow:global_step/sec: 193.853
# INFO:tensorflow:loss = 0.07410201, step = 12601 (0.516 sec)
# INFO:tensorflow:global_step/sec: 193.526
# INFO:tensorflow:loss = 0.06950593, step = 12701 (0.517 sec)
# INFO:tensorflow:global_step/sec: 192.274
# INFO:tensorflow:loss = 0.06612766, step = 12801 (0.519 sec)
# INFO:tensorflow:global_step/sec: 190.182
# INFO:tensorflow:loss = 0.07839294, step = 12901 (0.526 sec)
# INFO:tensorflow:global_step/sec: 193.435
# INFO:tensorflow:loss = 0.0787436, step = 13001 (0.517 sec)
# INFO:tensorflow:global_step/sec: 195.748
# INFO:tensorflow:loss = 0.069014564, step = 13101 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.293
# INFO:tensorflow:loss = 0.06783873, step = 13201 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.284
# INFO:tensorflow:loss = 0.06785157, step = 13301 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.951
# INFO:tensorflow:loss = 0.07304537, step = 13401 (0.518 sec)
# INFO:tensorflow:global_step/sec: 193.609
# INFO:tensorflow:loss = 0.063855514, step = 13501 (0.517 sec)
# INFO:tensorflow:global_step/sec: 194.81
# INFO:tensorflow:loss = 0.074826404, step = 13601 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.191
# INFO:tensorflow:loss = 0.074860096, step = 13701 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.951
# INFO:tensorflow:loss = 0.077660814, step = 13801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 190.999
# INFO:tensorflow:loss = 0.07812798, step = 13901 (0.524 sec)
# INFO:tensorflow:global_step/sec: 194.534
# INFO:tensorflow:loss = 0.07996583, step = 14001 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.57
# INFO:tensorflow:loss = 0.066004544, step = 14101 (0.516 sec)
# INFO:tensorflow:global_step/sec: 193.564
# INFO:tensorflow:loss = 0.06346787, step = 14201 (0.515 sec)
# INFO:tensorflow:global_step/sec: 196.408
# INFO:tensorflow:loss = 0.060134854, step = 14301 (0.509 sec)
# INFO:tensorflow:global_step/sec: 194.691
# INFO:tensorflow:loss = 0.061296664, step = 14401 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.805
# INFO:tensorflow:loss = 0.07096471, step = 14501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 193.347
# INFO:tensorflow:loss = 0.07009504, step = 14601 (0.517 sec)
# INFO:tensorflow:global_step/sec: 195.115
# INFO:tensorflow:loss = 0.056405324, step = 14701 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.054
# INFO:tensorflow:loss = 0.056214724, step = 14801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.819
# INFO:tensorflow:loss = 0.071995735, step = 14901 (0.513 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./mnist_convnet_student_mod_t_1_w_0.25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.06231386.
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:49:40
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.25/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:49:42
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.7589168, global_step = 15000, loss = 0.8178701
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:49:42
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.25/model.ckpt-15000
# Exception in thread Thread-1086:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:49:42
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.7688228, global_step = 15000, loss = 0.7950935
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f259a9a5750>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './mnist_convnet_student_mod_t_1_w_0.5', '_save_summary_steps': 100}
# {'x': <tf.Tensor 'Const:0' shape=(100, 784) dtype=float32>} Tensor("Const_1:0", shape=(100,), dtype=int32, device=/device:CPU:0)
# _THIS_ <type 'dict'>
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:49:43
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:49:43
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.98, global_step = 20000, loss = 0.09350607
# _THIS_ <type 'dict'>
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.5/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into ./mnist_convnet_student_mod_t_1_w_0.5/model.ckpt.
# INFO:tensorflow:loss = 0.04598814, step = 10001
# INFO:tensorflow:global_step/sec: 171.785
# INFO:tensorflow:loss = 0.062028185, step = 10101 (0.583 sec)
# INFO:tensorflow:global_step/sec: 194.958
# INFO:tensorflow:loss = 0.045925662, step = 10201 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.906
# INFO:tensorflow:loss = 0.045128886, step = 10301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.095
# INFO:tensorflow:loss = 0.045122012, step = 10401 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.931
# INFO:tensorflow:loss = 0.042792518, step = 10501 (0.508 sec)
# INFO:tensorflow:global_step/sec: 193.985
# INFO:tensorflow:loss = 0.05014988, step = 10601 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.941
# INFO:tensorflow:loss = 0.045345843, step = 10701 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.621
# INFO:tensorflow:loss = 0.04294441, step = 10801 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.265
# INFO:tensorflow:loss = 0.06372536, step = 10901 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.922
# INFO:tensorflow:loss = 0.043695167, step = 11001 (0.516 sec)
# INFO:tensorflow:global_step/sec: 195.271
# INFO:tensorflow:loss = 0.07192924, step = 11101 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.897
# INFO:tensorflow:loss = 0.050533734, step = 11201 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.016
# INFO:tensorflow:loss = 0.056846514, step = 11301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.464
# INFO:tensorflow:loss = 0.042438664, step = 11401 (0.517 sec)
# INFO:tensorflow:global_step/sec: 196.511
# INFO:tensorflow:loss = 0.042844903, step = 11501 (0.509 sec)
# INFO:tensorflow:global_step/sec: 195.139
# INFO:tensorflow:loss = 0.051221747, step = 11601 (0.512 sec)
# INFO:tensorflow:global_step/sec: 197.065
# INFO:tensorflow:loss = 0.039683595, step = 11701 (0.508 sec)
# INFO:tensorflow:global_step/sec: 190.583
# INFO:tensorflow:loss = 0.04035174, step = 11801 (0.525 sec)
# INFO:tensorflow:global_step/sec: 197.35
# INFO:tensorflow:loss = 0.039960727, step = 11901 (0.507 sec)
# INFO:tensorflow:global_step/sec: 195.191
# INFO:tensorflow:loss = 0.039399777, step = 12001 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.428
# INFO:tensorflow:loss = 0.04184037, step = 12101 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.111
# INFO:tensorflow:loss = 0.049494706, step = 12201 (0.515 sec)
# INFO:tensorflow:global_step/sec: 195.729
# INFO:tensorflow:loss = 0.041263163, step = 12301 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.756
# INFO:tensorflow:loss = 0.04072638, step = 12401 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.538
# INFO:tensorflow:loss = 0.037041314, step = 12501 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.863
# INFO:tensorflow:loss = 0.040748328, step = 12601 (0.511 sec)
# INFO:tensorflow:global_step/sec: 197.45
# INFO:tensorflow:loss = 0.035221774, step = 12701 (0.507 sec)
# INFO:tensorflow:global_step/sec: 195.454
# INFO:tensorflow:loss = 0.045820475, step = 12801 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.44
# INFO:tensorflow:loss = 0.039090663, step = 12901 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.771
# INFO:tensorflow:loss = 0.0395632, step = 13001 (0.513 sec)
# INFO:tensorflow:global_step/sec: 193.395
# INFO:tensorflow:loss = 0.037789732, step = 13101 (0.517 sec)
# INFO:tensorflow:global_step/sec: 193.967
# INFO:tensorflow:loss = 0.028507374, step = 13201 (0.516 sec)
# INFO:tensorflow:global_step/sec: 194.695
# INFO:tensorflow:loss = 0.026791565, step = 13301 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.438
# INFO:tensorflow:loss = 0.04059595, step = 13401 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.073
# INFO:tensorflow:loss = 0.036292948, step = 13501 (0.515 sec)
# INFO:tensorflow:global_step/sec: 189.629
# INFO:tensorflow:loss = 0.029706996, step = 13601 (0.527 sec)
# INFO:tensorflow:global_step/sec: 194.91
# INFO:tensorflow:loss = 0.03626395, step = 13701 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.466
# INFO:tensorflow:loss = 0.033601575, step = 13801 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.645
# INFO:tensorflow:loss = 0.03824542, step = 13901 (0.513 sec)
# INFO:tensorflow:global_step/sec: 181.348
# INFO:tensorflow:loss = 0.034694646, step = 14001 (0.551 sec)
# INFO:tensorflow:global_step/sec: 190.677
# INFO:tensorflow:loss = 0.03867152, step = 14101 (0.524 sec)
# INFO:tensorflow:global_step/sec: 196.291
# INFO:tensorflow:loss = 0.028897684, step = 14201 (0.510 sec)
# INFO:tensorflow:global_step/sec: 197.29
# INFO:tensorflow:loss = 0.026496863, step = 14301 (0.506 sec)
# INFO:tensorflow:global_step/sec: 196.136
# INFO:tensorflow:loss = 0.030768776, step = 14401 (0.510 sec)
# INFO:tensorflow:global_step/sec: 195.108
# INFO:tensorflow:loss = 0.030050296, step = 14501 (0.512 sec)
# INFO:tensorflow:global_step/sec: 196.084
# INFO:tensorflow:loss = 0.029914696, step = 14601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.937
# INFO:tensorflow:loss = 0.02959666, step = 14701 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.837
# INFO:tensorflow:loss = 0.035775304, step = 14801 (0.511 sec)
# INFO:tensorflow:global_step/sec: 194.659
# INFO:tensorflow:loss = 0.02984367, step = 14901 (0.514 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./mnist_convnet_student_mod_t_1_w_0.5/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.030072035.
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# Exception in thread Thread-1093:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:50:10
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.5/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:50:12
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.75503516, global_step = 15000, loss = 0.95766884
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:50:12
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.5/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:50:12
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.76320714, global_step = 15000, loss = 0.9395068
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2597751810>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './mnist_convnet_student_mod_t_1_w_0.75', '_save_summary_steps': 100}
# {'x': <tf.Tensor 'Const:0' shape=(100, 784) dtype=float32>} Tensor("Const_1:0", shape=(100,), dtype=int32, device=/device:CPU:0)
# _THIS_ <type 'dict'>
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:50:12
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:50:13
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.96, global_step = 20000, loss = 0.10454481
# _THIS_ <type 'dict'>
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.75/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into ./mnist_convnet_student_mod_t_1_w_0.75/model.ckpt.
# INFO:tensorflow:loss = 0.028023131, step = 10001
# INFO:tensorflow:global_step/sec: 169.496
# INFO:tensorflow:loss = 0.036143497, step = 10101 (0.596 sec)
# INFO:tensorflow:global_step/sec: 192.04
# INFO:tensorflow:loss = 0.041561984, step = 10201 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.823
# INFO:tensorflow:loss = 0.026761634, step = 10301 (0.518 sec)
# INFO:tensorflow:global_step/sec: 195.142
# INFO:tensorflow:loss = 0.02836914, step = 10401 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.148
# INFO:tensorflow:loss = 0.03235422, step = 10501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 196.225
# INFO:tensorflow:loss = 0.027083304, step = 10601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.171
# INFO:tensorflow:loss = 0.020047802, step = 10701 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.433
# INFO:tensorflow:loss = 0.028279025, step = 10801 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.075
# INFO:tensorflow:loss = 0.04465786, step = 10901 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.097
# INFO:tensorflow:loss = 0.034880716, step = 11001 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.267
# INFO:tensorflow:loss = 0.028439252, step = 11101 (0.517 sec)
# INFO:tensorflow:global_step/sec: 195.896
# INFO:tensorflow:loss = 0.02858825, step = 11201 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.787
# INFO:tensorflow:loss = 0.030178927, step = 11301 (0.516 sec)
# INFO:tensorflow:global_step/sec: 193.679
# INFO:tensorflow:loss = 0.036760982, step = 11401 (0.516 sec)
# INFO:tensorflow:global_step/sec: 195.63
# INFO:tensorflow:loss = 0.035045676, step = 11501 (0.511 sec)
# INFO:tensorflow:global_step/sec: 193.759
# INFO:tensorflow:loss = 0.027393164, step = 11601 (0.516 sec)
# INFO:tensorflow:global_step/sec: 193.522
# INFO:tensorflow:loss = 0.023953266, step = 11701 (0.517 sec)
# INFO:tensorflow:global_step/sec: 194.385
# INFO:tensorflow:loss = 0.019870903, step = 11801 (0.514 sec)
# INFO:tensorflow:global_step/sec: 197.11
# INFO:tensorflow:loss = 0.02293478, step = 11901 (0.507 sec)
# INFO:tensorflow:global_step/sec: 191.431
# INFO:tensorflow:loss = 0.041897472, step = 12001 (0.522 sec)
# INFO:tensorflow:global_step/sec: 192.436
# INFO:tensorflow:loss = 0.026123129, step = 12101 (0.520 sec)
# INFO:tensorflow:global_step/sec: 195.83
# INFO:tensorflow:loss = 0.034020036, step = 12201 (0.511 sec)
# INFO:tensorflow:global_step/sec: 192.237
# INFO:tensorflow:loss = 0.026115436, step = 12301 (0.520 sec)
# INFO:tensorflow:global_step/sec: 196.557
# INFO:tensorflow:loss = 0.02449587, step = 12401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 194.627
# INFO:tensorflow:loss = 0.028359644, step = 12501 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.656
# INFO:tensorflow:loss = 0.027916992, step = 12601 (0.511 sec)
# INFO:tensorflow:global_step/sec: 193.535
# INFO:tensorflow:loss = 0.02036189, step = 12701 (0.517 sec)
# INFO:tensorflow:global_step/sec: 194.957
# INFO:tensorflow:loss = 0.023799907, step = 12801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.539
# INFO:tensorflow:loss = 0.023999326, step = 12901 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.382
# INFO:tensorflow:loss = 0.021430809, step = 13001 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.625
# INFO:tensorflow:loss = 0.01962875, step = 13101 (0.511 sec)
# INFO:tensorflow:global_step/sec: 192.627
# INFO:tensorflow:loss = 0.031247593, step = 13201 (0.519 sec)
# INFO:tensorflow:global_step/sec: 191.793
# INFO:tensorflow:loss = 0.02423081, step = 13301 (0.521 sec)
# INFO:tensorflow:global_step/sec: 194.669
# INFO:tensorflow:loss = 0.018689215, step = 13401 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.807
# INFO:tensorflow:loss = 0.03348569, step = 13501 (0.514 sec)
# INFO:tensorflow:global_step/sec: 191.123
# INFO:tensorflow:loss = 0.03375595, step = 13601 (0.523 sec)
# INFO:tensorflow:global_step/sec: 195.762
# INFO:tensorflow:loss = 0.02385984, step = 13701 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.139
# INFO:tensorflow:loss = 0.019468468, step = 13801 (0.510 sec)
# INFO:tensorflow:global_step/sec: 188.57
# INFO:tensorflow:loss = 0.018486954, step = 13901 (0.531 sec)
# INFO:tensorflow:global_step/sec: 192.868
# INFO:tensorflow:loss = 0.028486453, step = 14001 (0.517 sec)
# INFO:tensorflow:global_step/sec: 189.282
# INFO:tensorflow:loss = 0.020491226, step = 14101 (0.530 sec)
# INFO:tensorflow:global_step/sec: 194.416
# INFO:tensorflow:loss = 0.0297768, step = 14201 (0.512 sec)
# INFO:tensorflow:global_step/sec: 187.583
# INFO:tensorflow:loss = 0.023954941, step = 14301 (0.533 sec)
# INFO:tensorflow:global_step/sec: 192.477
# INFO:tensorflow:loss = 0.017585585, step = 14401 (0.520 sec)
# INFO:tensorflow:global_step/sec: 194.974
# INFO:tensorflow:loss = 0.019068185, step = 14501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.623
# INFO:tensorflow:loss = 0.022787748, step = 14601 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.502
# INFO:tensorflow:loss = 0.022283059, step = 14701 (0.511 sec)
# INFO:tensorflow:global_step/sec: 191.467
# INFO:tensorflow:loss = 0.017775178, step = 14801 (0.523 sec)
# INFO:tensorflow:global_step/sec: 192.109
# INFO:tensorflow:loss = 0.020824134, step = 14901 (0.520 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./mnist_convnet_student_mod_t_1_w_0.75/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.021539059.
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:50:40
# Exception in thread Thread-1103:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.75/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:50:42
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.7696463, global_step = 15000, loss = 0.9567322
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:50:42
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_0.75/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:50:42
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.7829659, global_step = 15000, loss = 0.9030881
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f259a9ad6d0>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './mnist_convnet_student_mod_t_1_w_1', '_save_summary_steps': 100}
# {'x': <tf.Tensor 'Const:0' shape=(100, 784) dtype=float32>} Tensor("Const_1:0", shape=(100,), dtype=int32, device=/device:CPU:0)
# _THIS_ <type 'dict'>
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:50:42
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:50:43
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 1.0, global_step = 20000, loss = 0.04139505
# _THIS_ <type 'dict'>
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_1/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into ./mnist_convnet_student_mod_t_1_w_1/model.ckpt.
# INFO:tensorflow:loss = 0.009364049, step = 10001
# INFO:tensorflow:global_step/sec: 157.322
# INFO:tensorflow:loss = 0.009907476, step = 10101 (0.636 sec)
# INFO:tensorflow:global_step/sec: 187.796
# INFO:tensorflow:loss = 0.025256416, step = 10201 (0.532 sec)
# INFO:tensorflow:global_step/sec: 193.679
# INFO:tensorflow:loss = 0.009372017, step = 10301 (0.516 sec)
# INFO:tensorflow:global_step/sec: 195.916
# INFO:tensorflow:loss = 0.015690176, step = 10401 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.411
# INFO:tensorflow:loss = 0.015124615, step = 10501 (0.519 sec)
# INFO:tensorflow:global_step/sec: 182.515
# INFO:tensorflow:loss = 0.018405372, step = 10601 (0.547 sec)
# INFO:tensorflow:global_step/sec: 181.741
# INFO:tensorflow:loss = 0.008470565, step = 10701 (0.551 sec)
# INFO:tensorflow:global_step/sec: 187.103
# INFO:tensorflow:loss = 0.014994104, step = 10801 (0.533 sec)
# INFO:tensorflow:global_step/sec: 194.209
# INFO:tensorflow:loss = 0.00762406, step = 10901 (0.515 sec)
# INFO:tensorflow:global_step/sec: 195.782
# INFO:tensorflow:loss = 0.012816416, step = 11001 (0.511 sec)
# INFO:tensorflow:global_step/sec: 193.654
# INFO:tensorflow:loss = 0.011575109, step = 11101 (0.516 sec)
# INFO:tensorflow:global_step/sec: 194.99
# INFO:tensorflow:loss = 0.026720962, step = 11201 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.62
# INFO:tensorflow:loss = 0.013203171, step = 11301 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.468
# INFO:tensorflow:loss = 0.014477697, step = 11401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 194.529
# INFO:tensorflow:loss = 0.010196055, step = 11501 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.909
# INFO:tensorflow:loss = 0.017310334, step = 11601 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.711
# INFO:tensorflow:loss = 0.007922872, step = 11701 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.89
# INFO:tensorflow:loss = 0.012603415, step = 11801 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.895
# INFO:tensorflow:loss = 0.0063970396, step = 11901 (0.516 sec)
# INFO:tensorflow:global_step/sec: 192.931
# INFO:tensorflow:loss = 0.021343185, step = 12001 (0.518 sec)
# INFO:tensorflow:global_step/sec: 195.519
# INFO:tensorflow:loss = 0.018848091, step = 12101 (0.511 sec)
# INFO:tensorflow:global_step/sec: 193.007
# INFO:tensorflow:loss = 0.015065355, step = 12201 (0.518 sec)
# INFO:tensorflow:global_step/sec: 196.065
# INFO:tensorflow:loss = 0.01383496, step = 12301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.997
# INFO:tensorflow:loss = 0.007010012, step = 12401 (0.508 sec)
# INFO:tensorflow:global_step/sec: 194.901
# INFO:tensorflow:loss = 0.012975062, step = 12501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 197.01
# INFO:tensorflow:loss = 0.0077166385, step = 12601 (0.508 sec)
# INFO:tensorflow:global_step/sec: 192.757
# INFO:tensorflow:loss = 0.010194306, step = 12701 (0.519 sec)
# INFO:tensorflow:global_step/sec: 194.437
# INFO:tensorflow:loss = 0.009730759, step = 12801 (0.514 sec)
# INFO:tensorflow:global_step/sec: 197.427
# INFO:tensorflow:loss = 0.008755504, step = 12901 (0.507 sec)
# INFO:tensorflow:global_step/sec: 194.11
# INFO:tensorflow:loss = 0.018535938, step = 13001 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.552
# INFO:tensorflow:loss = 0.015727, step = 13101 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.955
# INFO:tensorflow:loss = 0.015566425, step = 13201 (0.518 sec)
# INFO:tensorflow:global_step/sec: 195.834
# INFO:tensorflow:loss = 0.009982677, step = 13301 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.314
# INFO:tensorflow:loss = 0.026937578, step = 13401 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.24
# INFO:tensorflow:loss = 0.0060207522, step = 13501 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.849
# INFO:tensorflow:loss = 0.010530978, step = 13601 (0.513 sec)
# INFO:tensorflow:global_step/sec: 196.455
# INFO:tensorflow:loss = 0.025096979, step = 13701 (0.509 sec)
# INFO:tensorflow:global_step/sec: 196.441
# INFO:tensorflow:loss = 0.0039074128, step = 13801 (0.510 sec)
# INFO:tensorflow:global_step/sec: 191.72
# INFO:tensorflow:loss = 0.007928337, step = 13901 (0.522 sec)
# INFO:tensorflow:global_step/sec: 192.951
# INFO:tensorflow:loss = 0.008324084, step = 14001 (0.517 sec)
# INFO:tensorflow:global_step/sec: 191.996
# INFO:tensorflow:loss = 0.009884636, step = 14101 (0.521 sec)
# INFO:tensorflow:global_step/sec: 194.593
# INFO:tensorflow:loss = 0.009679354, step = 14201 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.099
# INFO:tensorflow:loss = 0.01053746, step = 14301 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.227
# INFO:tensorflow:loss = 0.008898196, step = 14401 (0.517 sec)
# INFO:tensorflow:global_step/sec: 193.69
# INFO:tensorflow:loss = 0.015050705, step = 14501 (0.516 sec)
# INFO:tensorflow:global_step/sec: 196.215
# INFO:tensorflow:loss = 0.017301746, step = 14601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.266
# INFO:tensorflow:loss = 0.011064504, step = 14701 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.903
# INFO:tensorflow:loss = 0.011580366, step = 14801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.234
# INFO:tensorflow:loss = 0.007287562, step = 14901 (0.512 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./mnist_convnet_student_mod_t_1_w_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.009046206.
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:51:10
# Exception in thread Thread-1113:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_1/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:51:12
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.7829208, global_step = 15000, loss = 0.97952604
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:51:12
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_1_w_1/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:51:12
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.7896215, global_step = 15000, loss = 0.9558685
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2597786d10>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './mnist_convnet_student_mod_t_2_w_0', '_save_summary_steps': 100}
# {'x': <tf.Tensor 'Const:0' shape=(100, 784) dtype=float32>} Tensor("Const_1:0", shape=(100,), dtype=int32, device=/device:CPU:0)
# _THIS_ <type 'dict'>
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:51:12
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:51:13
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.97, global_step = 20000, loss = 0.08945859
# _THIS_ <type 'dict'>
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_2_w_0/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into ./mnist_convnet_student_mod_t_2_w_0/model.ckpt.
# INFO:tensorflow:loss = 0.22744296, step = 10001
# INFO:tensorflow:global_step/sec: 168.333
# INFO:tensorflow:loss = 0.22781067, step = 10101 (0.595 sec)
# INFO:tensorflow:global_step/sec: 173.025
# INFO:tensorflow:loss = 0.22723697, step = 10201 (0.580 sec)
# INFO:tensorflow:global_step/sec: 182.063
# INFO:tensorflow:loss = 0.22711772, step = 10301 (0.548 sec)
# INFO:tensorflow:global_step/sec: 194.255
# INFO:tensorflow:loss = 0.22688942, step = 10401 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.427
# INFO:tensorflow:loss = 0.22738239, step = 10501 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.09
# INFO:tensorflow:loss = 0.22773941, step = 10601 (0.515 sec)
# INFO:tensorflow:global_step/sec: 173.527
# INFO:tensorflow:loss = 0.22723547, step = 10701 (0.576 sec)
# INFO:tensorflow:global_step/sec: 192.276
# INFO:tensorflow:loss = 0.22735077, step = 10801 (0.520 sec)
# INFO:tensorflow:global_step/sec: 194.427
# INFO:tensorflow:loss = 0.2266465, step = 10901 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.9
# INFO:tensorflow:loss = 0.22640207, step = 11001 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.135
# INFO:tensorflow:loss = 0.22696877, step = 11101 (0.510 sec)
# INFO:tensorflow:global_step/sec: 197.478
# INFO:tensorflow:loss = 0.2261745, step = 11201 (0.506 sec)
# INFO:tensorflow:global_step/sec: 194.363
# INFO:tensorflow:loss = 0.22753051, step = 11301 (0.515 sec)
# INFO:tensorflow:global_step/sec: 195.501
# INFO:tensorflow:loss = 0.22642873, step = 11401 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.827
# INFO:tensorflow:loss = 0.2271044, step = 11501 (0.508 sec)
# INFO:tensorflow:global_step/sec: 190.992
# INFO:tensorflow:loss = 0.22680509, step = 11601 (0.524 sec)
# INFO:tensorflow:global_step/sec: 194.652
# INFO:tensorflow:loss = 0.22688827, step = 11701 (0.514 sec)
# INFO:tensorflow:global_step/sec: 192.358
# INFO:tensorflow:loss = 0.22670965, step = 11801 (0.520 sec)
# INFO:tensorflow:global_step/sec: 194.307
# INFO:tensorflow:loss = 0.22664163, step = 11901 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.26
# INFO:tensorflow:loss = 0.22664285, step = 12001 (0.522 sec)
# INFO:tensorflow:global_step/sec: 191.544
# INFO:tensorflow:loss = 0.22606179, step = 12101 (0.521 sec)
# INFO:tensorflow:global_step/sec: 196.198
# INFO:tensorflow:loss = 0.22668347, step = 12201 (0.509 sec)
# INFO:tensorflow:global_step/sec: 195.628
# INFO:tensorflow:loss = 0.22662356, step = 12301 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.742
# INFO:tensorflow:loss = 0.22588904, step = 12401 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.035
# INFO:tensorflow:loss = 0.22523032, step = 12501 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.508
# INFO:tensorflow:loss = 0.22717819, step = 12601 (0.509 sec)
# INFO:tensorflow:global_step/sec: 195.558
# INFO:tensorflow:loss = 0.22635739, step = 12701 (0.511 sec)
# INFO:tensorflow:global_step/sec: 194.353
# INFO:tensorflow:loss = 0.22604527, step = 12801 (0.514 sec)
# INFO:tensorflow:global_step/sec: 196.255
# INFO:tensorflow:loss = 0.22562993, step = 12901 (0.510 sec)
# INFO:tensorflow:global_step/sec: 192.032
# INFO:tensorflow:loss = 0.2249108, step = 13001 (0.521 sec)
# INFO:tensorflow:global_step/sec: 195.712
# INFO:tensorflow:loss = 0.22597092, step = 13101 (0.511 sec)
# INFO:tensorflow:global_step/sec: 194.23
# INFO:tensorflow:loss = 0.22590832, step = 13201 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.811
# INFO:tensorflow:loss = 0.22489554, step = 13301 (0.513 sec)
# INFO:tensorflow:global_step/sec: 189.651
# ...
# INFO:tensorflow:loss = 0.12464474, step = 10501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.183
# INFO:tensorflow:loss = 0.098118775, step = 10601 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.593
# INFO:tensorflow:loss = 0.10983523, step = 10701 (0.519 sec)
# INFO:tensorflow:global_step/sec: 195.487
# INFO:tensorflow:loss = 0.10088968, step = 10801 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.286
# INFO:tensorflow:loss = 0.083215535, step = 10901 (0.515 sec)
# INFO:tensorflow:global_step/sec: 195.768
# INFO:tensorflow:loss = 0.1119114, step = 11001 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.328
# INFO:tensorflow:loss = 0.100256376, step = 11101 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.039
# INFO:tensorflow:loss = 0.096023, step = 11201 (0.513 sec)
# INFO:tensorflow:global_step/sec: 196.09
# INFO:tensorflow:loss = 0.098194346, step = 11301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.625
# INFO:tensorflow:loss = 0.0996468, step = 11401 (0.514 sec)
# INFO:tensorflow:global_step/sec: 188.58
# INFO:tensorflow:loss = 0.11543636, step = 11501 (0.531 sec)
# INFO:tensorflow:global_step/sec: 193.098
# INFO:tensorflow:loss = 0.093187705, step = 11601 (0.517 sec)
# INFO:tensorflow:global_step/sec: 195.577
# INFO:tensorflow:loss = 0.09077543, step = 11701 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.977
# INFO:tensorflow:loss = 0.09448737, step = 11801 (0.510 sec)
# INFO:tensorflow:global_step/sec: 195.48
# INFO:tensorflow:loss = 0.09752302, step = 11901 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.58
# INFO:tensorflow:loss = 0.09522472, step = 12001 (0.514 sec)
# INFO:tensorflow:global_step/sec: 192.167
# INFO:tensorflow:loss = 0.08506856, step = 12101 (0.520 sec)
# INFO:tensorflow:global_step/sec: 193.717
# INFO:tensorflow:loss = 0.080875896, step = 12201 (0.516 sec)
# INFO:tensorflow:global_step/sec: 192.83
# INFO:tensorflow:loss = 0.094108686, step = 12301 (0.519 sec)
# INFO:tensorflow:global_step/sec: 195.205
# INFO:tensorflow:loss = 0.080534585, step = 12401 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.466
# INFO:tensorflow:loss = 0.08210379, step = 12501 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.366
# INFO:tensorflow:loss = 0.08676193, step = 12601 (0.516 sec)
# INFO:tensorflow:global_step/sec: 192.161
# INFO:tensorflow:loss = 0.076817036, step = 12701 (0.520 sec)
# INFO:tensorflow:global_step/sec: 193.55
# INFO:tensorflow:loss = 0.085825495, step = 12801 (0.517 sec)
# INFO:tensorflow:global_step/sec: 194.634
# INFO:tensorflow:loss = 0.083284274, step = 12901 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.306
# INFO:tensorflow:loss = 0.091642834, step = 13001 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.007
# INFO:tensorflow:loss = 0.083203085, step = 13101 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.019
# INFO:tensorflow:loss = 0.08116089, step = 13201 (0.521 sec)
# INFO:tensorflow:global_step/sec: 194.234
# INFO:tensorflow:loss = 0.08220953, step = 13301 (0.515 sec)
# INFO:tensorflow:global_step/sec: 195.564
# INFO:tensorflow:loss = 0.07570483, step = 13401 (0.511 sec)
# INFO:tensorflow:global_step/sec: 194.947
# INFO:tensorflow:loss = 0.08060023, step = 13501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.303
# INFO:tensorflow:loss = 0.079865195, step = 13601 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.107
# INFO:tensorflow:loss = 0.07341011, step = 13701 (0.515 sec)
# INFO:tensorflow:global_step/sec: 196.744
# INFO:tensorflow:loss = 0.08147618, step = 13801 (0.508 sec)
# INFO:tensorflow:global_step/sec: 189.967
# INFO:tensorflow:loss = 0.08581245, step = 13901 (0.527 sec)
# INFO:tensorflow:global_step/sec: 194.961
# INFO:tensorflow:loss = 0.07954316, step = 14001 (0.512 sec)
# INFO:tensorflow:global_step/sec: 189.376
# INFO:tensorflow:loss = 0.084716275, step = 14101 (0.528 sec)
# INFO:tensorflow:global_step/sec: 195.969
# INFO:tensorflow:loss = 0.08059792, step = 14201 (0.510 sec)
# INFO:tensorflow:global_step/sec: 195.873
# INFO:tensorflow:loss = 0.08350904, step = 14301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.763
# INFO:tensorflow:loss = 0.08009761, step = 14401 (0.516 sec)
# INFO:tensorflow:global_step/sec: 194.631
# INFO:tensorflow:loss = 0.08686681, step = 14501 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.945
# INFO:tensorflow:loss = 0.086272225, step = 14601 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.516
# INFO:tensorflow:loss = 0.07341735, step = 14701 (0.511 sec)
# INFO:tensorflow:global_step/sec: 187.253
# INFO:tensorflow:loss = 0.07507533, step = 14801 (0.534 sec)
# INFO:tensorflow:global_step/sec: 194.302
# INFO:tensorflow:loss = 0.07658172, step = 14901 (0.515 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./mnist_convnet_student_mod_t_10_w_0.75/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.07530098.
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:58:11
# Exception in thread Thread-1253:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_10_w_0.75/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:58:13
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.8176908, global_step = 15000, loss = 0.75486296
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:58:13
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_10_w_0.75/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:58:13
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.82570714, global_step = 15000, loss = 0.7271139
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f25904b3ad0>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './mnist_convnet_student_mod_t_10_w_1', '_save_summary_steps': 100}
# {'x': <tf.Tensor 'Const:0' shape=(100, 784) dtype=float32>} Tensor("Const_1:0", shape=(100,), dtype=int32, device=/device:CPU:0)
# _THIS_ <type 'dict'>
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:58:13
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:58:14
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.97, global_step = 20000, loss = 0.09986788
# _THIS_ <type 'dict'>
# INFO:tensorflow:Restoring parameters from /tmp/mnist_convnet_model_test1/model.ckpt-20000
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_10_w_1/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into ./mnist_convnet_student_mod_t_10_w_1/model.ckpt.
# INFO:tensorflow:loss = 0.024309572, step = 10001
# INFO:tensorflow:global_step/sec: 148.168
# INFO:tensorflow:loss = 0.041315097, step = 10101 (0.676 sec)
# INFO:tensorflow:global_step/sec: 183.922
# INFO:tensorflow:loss = 0.054080665, step = 10201 (0.544 sec)
# INFO:tensorflow:global_step/sec: 192.757
# INFO:tensorflow:loss = 0.048089046, step = 10301 (0.517 sec)
# INFO:tensorflow:global_step/sec: 186.349
# INFO:tensorflow:loss = 0.027929101, step = 10401 (0.537 sec)
# INFO:tensorflow:global_step/sec: 195.889
# INFO:tensorflow:loss = 0.02586631, step = 10501 (0.510 sec)
# INFO:tensorflow:global_step/sec: 195.908
# INFO:tensorflow:loss = 0.017971704, step = 10601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 197.865
# INFO:tensorflow:loss = 0.035953015, step = 10701 (0.505 sec)
# INFO:tensorflow:global_step/sec: 195.075
# INFO:tensorflow:loss = 0.033260044, step = 10801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.878
# INFO:tensorflow:loss = 0.024114655, step = 10901 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.058
# INFO:tensorflow:loss = 0.020636711, step = 11001 (0.511 sec)
# INFO:tensorflow:global_step/sec: 195.571
# INFO:tensorflow:loss = 0.045679346, step = 11101 (0.511 sec)
# INFO:tensorflow:global_step/sec: 197.594
# INFO:tensorflow:loss = 0.014061174, step = 11201 (0.506 sec)
# INFO:tensorflow:global_step/sec: 194.84
# INFO:tensorflow:loss = 0.018608864, step = 11301 (0.513 sec)
# INFO:tensorflow:global_step/sec: 197.646
# INFO:tensorflow:loss = 0.036862407, step = 11401 (0.506 sec)
# INFO:tensorflow:global_step/sec: 193.924
# INFO:tensorflow:loss = 0.031744827, step = 11501 (0.516 sec)
# INFO:tensorflow:global_step/sec: 194.908
# INFO:tensorflow:loss = 0.036127295, step = 11601 (0.513 sec)
# INFO:tensorflow:global_step/sec: 194.844
# INFO:tensorflow:loss = 0.02762023, step = 11701 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.295
# INFO:tensorflow:loss = 0.020935982, step = 11801 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.512
# INFO:tensorflow:loss = 0.022290535, step = 11901 (0.514 sec)
# INFO:tensorflow:global_step/sec: 195.142
# INFO:tensorflow:loss = 0.022578472, step = 12001 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.176
# INFO:tensorflow:loss = 0.022925314, step = 12101 (0.512 sec)
# INFO:tensorflow:global_step/sec: 193.637
# INFO:tensorflow:loss = 0.012604851, step = 12201 (0.516 sec)
# INFO:tensorflow:global_step/sec: 197.168
# INFO:tensorflow:loss = 0.016512152, step = 12301 (0.507 sec)
# INFO:tensorflow:global_step/sec: 194.326
# INFO:tensorflow:loss = 0.033166945, step = 12401 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.328
# INFO:tensorflow:loss = 0.032219686, step = 12501 (0.520 sec)
# INFO:tensorflow:global_step/sec: 194.528
# INFO:tensorflow:loss = 0.012321171, step = 12601 (0.514 sec)
# INFO:tensorflow:global_step/sec: 196.252
# INFO:tensorflow:loss = 0.03036734, step = 12701 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.222
# INFO:tensorflow:loss = 0.016168606, step = 12801 (0.514 sec)
# INFO:tensorflow:global_step/sec: 188.865
# INFO:tensorflow:loss = 0.025682725, step = 12901 (0.530 sec)
# INFO:tensorflow:global_step/sec: 195.858
# INFO:tensorflow:loss = 0.0063237376, step = 13001 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.109
# INFO:tensorflow:loss = 0.012255849, step = 13101 (0.510 sec)
# INFO:tensorflow:global_step/sec: 195.946
# INFO:tensorflow:loss = 0.016867895, step = 13201 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.372
# INFO:tensorflow:loss = 0.0164818, step = 13301 (0.509 sec)
# INFO:tensorflow:global_step/sec: 195.075
# INFO:tensorflow:loss = 0.015938083, step = 13401 (0.512 sec)
# INFO:tensorflow:global_step/sec: 196.358
# INFO:tensorflow:loss = 0.017238773, step = 13501 (0.509 sec)
# INFO:tensorflow:global_step/sec: 192.096
# INFO:tensorflow:loss = 0.025633885, step = 13601 (0.521 sec)
# INFO:tensorflow:global_step/sec: 194.541
# INFO:tensorflow:loss = 0.026803197, step = 13701 (0.514 sec)
# INFO:tensorflow:global_step/sec: 192.186
# INFO:tensorflow:loss = 0.039834704, step = 13801 (0.520 sec)
# INFO:tensorflow:global_step/sec: 193.684
# INFO:tensorflow:loss = 0.009973731, step = 13901 (0.516 sec)
# INFO:tensorflow:global_step/sec: 194.492
# INFO:tensorflow:loss = 0.016570527, step = 14001 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.935
# INFO:tensorflow:loss = 0.010094966, step = 14101 (0.515 sec)
# INFO:tensorflow:global_step/sec: 195.558
# INFO:tensorflow:loss = 0.010418793, step = 14201 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.095
# INFO:tensorflow:loss = 0.009279108, step = 14301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.315
# INFO:tensorflow:loss = 0.012164373, step = 14401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 195.165
# INFO:tensorflow:loss = 0.012105482, step = 14501 (0.512 sec)
# INFO:tensorflow:global_step/sec: 196.009
# INFO:tensorflow:loss = 0.029262094, step = 14601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 193.017
# INFO:tensorflow:loss = 0.010652008, step = 14701 (0.518 sec)
# INFO:tensorflow:global_step/sec: 196.095
# INFO:tensorflow:loss = 0.01611799, step = 14801 (0.510 sec)
# INFO:tensorflow:global_step/sec: 191.671
# INFO:tensorflow:loss = 0.0099984035, step = 14901 (0.522 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./mnist_convnet_student_mod_t_10_w_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.031792164.
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:58:41
# Exception in thread Thread-1263:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_10_w_1/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:58:43
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.7854658, global_step = 15000, loss = 0.8922863
# {'x': <tf.Tensor 'fifo_queue_DequeueUpTo:1' shape=(?, 784) dtype=float32>} Tensor("fifo_queue_DequeueUpTo:2", shape=(?,), dtype=int32, device=/device:CPU:0)
# ERROR:tensorflow:Exception in QueueRunner: Attempted to use a closed Session.
# INFO:tensorflow:Starting evaluation at 2018-05-06-18:58:43
# Exception in thread Thread-1266:
# Traceback (most recent call last):
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sanjay/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py", line 94, in _run
#     sess.run(enqueue_op, feed_dict=feed_dict)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 895, in run
#     run_metadata_ptr)
#   File "/home/sanjay/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 1053, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.
# INFO:tensorflow:Restoring parameters from ./mnist_convnet_student_mod_t_10_w_1/model.ckpt-15000
# INFO:tensorflow:Finished evaluation at 2018-05-06-18:58:43
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.79242927, global_step = 15000, loss = 0.8824561

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": eval_data},
  y=eval_labels,
  shuffle=False)
eval_result=student_classifier.evaluate(input_fn=eval_input_fn)

# %% [markdown]
# # loss1 + lamba * loss2

# %%
 
def custom_loss(y_true, pred_logits, tar_soft_t, pred_logits_t):
#    print(tf.losses.sparse_softmax_cross_entropy(labels = y_true, logits = pred_logits))
#    print(l * cross_entropy2(tar_soft_t, pred_logits_t))
   return tf.losses.sparse_softmax_cross_entropy(labels = y_true, logits = pred_logits) + lam * cross_entropy2(tar_soft_t, pred_logits_t)
mnist_classifier = tf.estimator.Estimator(
  model_fn=cnn_model_fn, model_dir="./models/mnist_convnet_model_test1")

mnist = tf.contrib.learn.datasets.load_dataset("mnist")
train_data = mnist.train.images  # Returns np.array
train_labels = np.asarray(mnist.train.labels, dtype=np.int32)
eval_data = mnist.test.images  # Returns np.array
eval_labels = np.asarray(mnist.test.labels, dtype=np.int32)
lam_list=[0,1,2,4,6,8,9,10]
temprature=2
out = open('out_lam.csv', 'w')
for i in lam_list:
    lam=i
    # Create the Estimator
    student_classifier = tf.estimator.Estimator(
      model_fn=student_model_fn, model_dir="./models/mnist_convnet_student_t_"+str(2)+"_lam_"+str(i))

    # Train the model
    train_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": train_data},
      y=train_labels,
      batch_size=100,
      num_epochs=None,
      shuffle=True)
    print(train_data,train_labels,eval_data,eval_labels)

    student_classifier.train(
      input_fn=train_input_fn,
      steps=20000,
      hooks=None)
    # print("eva",type(eval_data))

    # Evaluate the model and print results
    eval_train_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": train_data},
      y=train_labels,
      num_epochs=1,
      shuffle=False)
    train_result=student_classifier.evaluate(input_fn=eval_train_fn)

    out.write('%f;' % i)
    out.write('%f;' % j)
    out.write('%f;' % train_result['accuracy'])
    out.write('%f;' % train_result['loss'])

    eval_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": eval_data},
      y=eval_labels,
      num_epochs=1,
      shuffle=False)
    eval_result=student_classifier.evaluate(input_fn=eval_input_fn)
    # output=list(predictions)

    out.write('%f;' % eval_result['accuracy'])
    out.write('%f;' % eval_result['loss'])
#         acc=eval_result
#         out.write(eval_result)
    out.write('\n')

out.close()

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": train_data},
  y=train_labels,
  batch_size=100,
  num_epochs=10,
  shuffle=False)
eval_result=mnist_classifier.evaluate(input_fn=eval_input_fn)
